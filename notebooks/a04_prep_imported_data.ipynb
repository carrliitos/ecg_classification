# %% [markdown]
# ## Intro
#
# This notebook reads all the CSV files that were generated by notebook "a02_import_mitdb_data" and combines them all in 3 new CSV files that can be used for training your model. More specifically the following is done:
#
# - Read all CSV files generated by the "02_import_mitdb_data" notebook.
# - Shuffle all records randomly.
# - Save 60% of the records in a training CSV file.
# - Save 20% of the records in a validation CSV file.
# - Save 20% of the records in a test CSV file.

# %%
from glob import glob
import numpy as np

# %% [markdown]
# ## Load Data

# %%
alldata = np.empty(shape=[0, 188])
print(alldata.shape)
paths = glob('../data/processed/mitdb/*.csv')
for path in paths:
    print('Loading ', path)
    csvrows = np.loadtxt(path, delimiter=',')
    alldata = np.append(alldata, csvrows, axis=0)
# Out:
# (0, 188)
# Loading  ../data/processed/mitdb/213_MLII.csv
# Loading  ../data/processed/mitdb/207_MLII.csv
# Loading  ../data/processed/mitdb/217_V1.csv
# Loading  ../data/processed/mitdb/103_MLII.csv
# Loading  ../data/processed/mitdb/220_V1.csv
# Loading  ../data/processed/mitdb/232_V1.csv
# Loading  ../data/processed/mitdb/228_V1.csv
# Loading  ../data/processed/mitdb/200_V1.csv
# Loading  ../data/processed/mitdb/121_MLII.csv
# Loading  ../data/processed/mitdb/208_MLII.csv
# Loading  ../data/processed/mitdb/104_V5.csv
# Loading  ../data/processed/mitdb/100_V5.csv
# Loading  ../data/processed/mitdb/111_V1.csv
# Loading  ../data/processed/mitdb/115_V1.csv
# Loading  ../data/processed/mitdb/217_MLII.csv
# Loading  ../data/processed/mitdb/101_MLII.csv
# Loading  ../data/processed/mitdb/115_MLII.csv
# Loading  ../data/processed/mitdb/112_V1.csv
# Loading  ../data/processed/mitdb/101_V1.csv
# Loading  ../data/processed/mitdb/203_MLII.csv
# Loading  ../data/processed/mitdb/209_MLII.csv
# Loading  ../data/processed/mitdb/118_V1.csv
# Loading  ../data/processed/mitdb/234_MLII.csv
# Loading  ../data/processed/mitdb/230_MLII.csv
# Loading  ../data/processed/mitdb/219_V1.csv
# Loading  ../data/processed/mitdb/103_V2.csv
# Loading  ../data/processed/mitdb/108_V1.csv
# Loading  ../data/processed/mitdb/231_V1.csv
# Loading  ../data/processed/mitdb/233_V1.csv
# Loading  ../data/processed/mitdb/114_V5.csv
# Loading  ../data/processed/mitdb/123_V5.csv
# Loading  ../data/processed/mitdb/208_V1.csv
# Loading  ../data/processed/mitdb/108_MLII.csv
# Loading  ../data/processed/mitdb/205_V1.csv
# Loading  ../data/processed/mitdb/109_V1.csv
# Loading  ../data/processed/mitdb/202_V1.csv
# Loading  ../data/processed/mitdb/107_MLII.csv
# Loading  ../data/processed/mitdb/117_V2.csv
# Loading  ../data/processed/mitdb/116_V1.csv
# Loading  ../data/processed/mitdb/214_V1.csv
# Loading  ../data/processed/mitdb/230_V1.csv
# Loading  ../data/processed/mitdb/213_V1.csv
# Loading  ../data/processed/mitdb/113_V1.csv
# Loading  ../data/processed/mitdb/203_V1.csv
# Loading  ../data/processed/mitdb/215_V1.csv
# Loading  ../data/processed/mitdb/209_V1.csv
# Loading  ../data/processed/mitdb/233_MLII.csv
# Loading  ../data/processed/mitdb/210_MLII.csv
# Loading  ../data/processed/mitdb/201_V1.csv
# Loading  ../data/processed/mitdb/207_V1.csv
# Loading  ../data/processed/mitdb/102_V5.csv
# Loading  ../data/processed/mitdb/228_MLII.csv
# Loading  ../data/processed/mitdb/221_V1.csv
# Loading  ../data/processed/mitdb/212_V1.csv
# Loading  ../data/processed/mitdb/122_MLII.csv
# Loading  ../data/processed/mitdb/116_MLII.csv
# Loading  ../data/processed/mitdb/119_MLII.csv
# Loading  ../data/processed/mitdb/201_MLII.csv
# Loading  ../data/processed/mitdb/214_MLII.csv
# Loading  ../data/processed/mitdb/200_MLII.csv
# Loading  ../data/processed/mitdb/219_MLII.csv
# Loading  ../data/processed/mitdb/220_MLII.csv
# Loading  ../data/processed/mitdb/104_V2.csv
# Loading  ../data/processed/mitdb/124_V4.csv
# Loading  ../data/processed/mitdb/205_MLII.csv
# Loading  ../data/processed/mitdb/119_V1.csv
# Loading  ../data/processed/mitdb/121_V1.csv
# Loading  ../data/processed/mitdb/210_V1.csv
# Loading  ../data/processed/mitdb/102_V2.csv
# Loading  ../data/processed/mitdb/222_MLII.csv
# Loading  ../data/processed/mitdb/100_MLII.csv
# Loading  ../data/processed/mitdb/107_V1.csv
# Loading  ../data/processed/mitdb/222_V1.csv
# Loading  ../data/processed/mitdb/105_MLII.csv
# Loading  ../data/processed/mitdb/111_MLII.csv
# Loading  ../data/processed/mitdb/212_MLII.csv
# Loading  ../data/processed/mitdb/123_MLII.csv
# Loading  ../data/processed/mitdb/106_V1.csv
# Loading  ../data/processed/mitdb/117_MLII.csv
# Loading  ../data/processed/mitdb/202_MLII.csv
# Loading  ../data/processed/mitdb/221_MLII.csv
# Loading  ../data/processed/mitdb/234_V1.csv
# Loading  ../data/processed/mitdb/109_MLII.csv
# Loading  ../data/processed/mitdb/113_MLII.csv
# Loading  ../data/processed/mitdb/223_MLII.csv
# Loading  ../data/processed/mitdb/223_V1.csv
# Loading  ../data/processed/mitdb/215_MLII.csv
# Loading  ../data/processed/mitdb/122_V1.csv
# Loading  ../data/processed/mitdb/114_MLII.csv
# Loading  ../data/processed/mitdb/231_MLII.csv
# Loading  ../data/processed/mitdb/124_MLII.csv
# Loading  ../data/processed/mitdb/112_MLII.csv
# Loading  ../data/processed/mitdb/106_MLII.csv
# Loading  ../data/processed/mitdb/118_MLII.csv
# Loading  ../data/processed/mitdb/232_MLII.csv
# Loading  ../data/processed/mitdb/105_V1.csv

# %% [markdown]
# ## Shuffle and Separate
#
# All records are shuffled randomly, then split into training, validation, and testing groups.

# %%
np.random.shuffle(alldata)
totrows = len(alldata)
trainrows = int((totrows * 3 / 5) + 0.5) # 60%
testrows = int((totrows * 1 / 5) + 0.5) # 20%
validaterows = totrows - trainrows - testrows # 20%
mark1 = trainrows
mark2 = mark1 + testrows

# %% [markdown]
# ## Save Data
#
# Data is saved in 3 separate CSV files: training, validation, and testing.

# %%
with open('../data/interim/mitdb/train.csv', "wb") as fin:
    np.savetxt(fin, alldata[:mark1], delimiter=",", fmt='%f')

# %%
with open('../data/interim/mitdb/test.csv', "wb") as fin:
    np.savetxt(fin, alldata[mark1:mark2], delimiter=",", fmt='%f')

# %%
with open('../data/interim/mitdb/validate.csv', "wb") as fin:
    np.savetxt(fin, alldata[mark2:], delimiter=",", fmt='%f')
